# %%
from stats.stats import Stats

# %%
guangdong = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/guangdong_spider/guangdong_spider/spiders/guangdong_GDEA.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'GDEA', risk_free = 0.02388, start_date = '2020-03-01', end_date = '2021-03-01', to_csv = False)
guangdong.get_stats()
# Out:
# GDEA carbon market metrics from 2020-03-01 to 2021-03-01
# >> Total Return:  6.9953%
# >> Annualised return over months:  6.4403%
# >> Annualised return over years:  6.9953%
# >> Standard Deviation:  0.0136
# >> Annualised volatility:  0.2148
# >> Sharpe ratio:  0.2145
# >> Skewnesss:  0.2872
# >> Kurtosis:  1.64
# >> Maximum drawdown:  -12.32%

# %%
beijing = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/beijing_spider/beijing_spider/spiders/beijing_BEA.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'BEA', risk_free = 0.02388, start_date = '2020-03-01', end_date = '2021-03-01', to_csv = False)
beijing.get_stats()
# Out:
# BEA carbon market metrics from 2020-03-01 to 2021-03-01
# >> Total Return:  -55.8824%
# >> Annualised return over months:  -53.016%
# >> Annualised return over years:  -55.8824%
# >> Standard Deviation:  0.0946
# >> Annualised volatility:  1.496
# >> Sharpe ratio:  -0.3895
# >> Skewnesss:  -0.0686
# >> Kurtosis:  0.5395
# >> Maximum drawdown:  -70.86%

# %%
hubei = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/hubei_spider/hubei_spider/spiders/hubei_HBEA.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'HBEA', risk_free = 0.02388, start_date = '2020-03-01', end_date = '2021-03-01', to_csv = False)
hubei.get_stats()
# Out:
# HBEA carbon market metrics from 2020-03-01 to 2021-03-01
# >> Total Return:  17.1942%
# >> Annualised return over months:  15.7726%
# >> Annualised return over years:  17.1942%
# >> Standard Deviation:  0.0262
# >> Annualised volatility:  0.4136
# >> Sharpe ratio:  0.358
# >> Skewnesss:  0.1642
# >> Kurtosis:  4.7279
# >> Maximum drawdown:  -17.97%

# %%
chongqing = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/tanjiaoyi/chongqing_spider/chongqing_spider/spiders/chongqing_CQEA.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'CQEA', risk_free = 0.02388, start_date = '2020-03-01', end_date = '2021-03-01', to_csv = False)
chongqing.get_stats()
# Out:
# CQEA carbon market metrics from 2020-03-01 to 2021-03-01
# >> Total Return:  -24.4246%
# >> Annualised return over months:  -22.7789%
# >> Annualised return over years:  -24.4246%
# >> Standard Deviation:  0.1017
# >> Annualised volatility:  1.6086
# >> Sharpe ratio:  -0.1667
# >> Skewnesss:  2.3647
# >> Kurtosis:  18.2264
# >> Maximum drawdown:  -75.14%

# %%
fujian = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/tanjiaoyi/fujian_spider/fujian_spider/spiders/fujian_FJEA.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'FJEA', risk_free = 0.02388, start_date = '2020-03-01', end_date = '2021-03-01', to_csv = False)
fujian.get_stats()
# Out:
# FJEA carbon market metrics from 2020-03-01 to 2021-03-01
# >> Total Return:  -10.0%
# >> Annualised return over months:  -9.2676%
# >> Annualised return over years:  -10.0%
# >> Standard Deviation:  0.052
# >> Annualised volatility:  0.8217
# >> Sharpe ratio:  -0.1508
# >> Skewnesss:  -0.2019
# >> Kurtosis:  1.1716
# >> Maximum drawdown:  -69.23%

# %%
shenzhen = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/shenzhen_spider/shenzhen_spider/spiders/shenzhen_SZA_2015.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'SZA_2015', risk_free = 0.02388, start_date = '2020-03-01', end_date = '2021-03-01', to_csv = False)
shenzhen.get_stats()
# Out:
# SZA_2015 carbon market metrics from 2020-03-01 to 2021-03-01
# >> Total Return:  -53.3276%
# >> Annualised return over months:  -50.51%
# >> Annualised return over years:  -53.3276%
# >> Standard Deviation:  0.0659
# >> Annualised volatility:  1.0424
# >> Sharpe ratio:  -0.5345
# >> Skewnesss:  -0.0546
# >> Kurtosis:  -0.4754
# >> Maximum drawdown:  -92.22%

# %%
shanghai = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/tanjiaoyi/shanghai_spider/shanghai_spider/spiders/shanghai_SHEA.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'SHEA', risk_free = 0.02388, start_date = '2020-03-01', end_date = '2021-03-01', to_csv = False)
shanghai.get_stats()
# Out:
# SHEA carbon market metrics from 2020-03-01 to 2021-03-01
# >> Total Return:  -1.5007%
# >> Annualised return over months:  -1.3861%
# >> Annualised return over years:  -1.5007%
# >> Standard Deviation:  0.0572
# >> Annualised volatility:  0.9039
# >> Sharpe ratio:  -0.043
# >> Skewnesss:  1.019
# >> Kurtosis:  4.6876
# >> Maximum drawdown:  -42.22%

# %%
tianjin = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/tianjin_spider/tianjin_spider/spiders/tianjin_.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'TJEA', risk_free = 0.02388, start_date = '2020-03-01', end_date = '2021-03-01', to_csv = False)
tianjin.get_stats()
# Out:
# TJEA carbon market metrics from 2020-03-01 to 2021-03-01
# >> Total Return:  29.4118%
# >> Annualised return over months:  26.8704%
# >> Annualised return over years:  29.4118%
# >> Standard Deviation:  0.0318
# >> Annualised volatility:  0.5022
# >> Sharpe ratio:  0.5381
# >> Skewnesss:  -0.3764
# >> Kurtosis:  3.2119
# >> Maximum drawdown:  -25.0%

# %%
from stats.stats import Correlation

# %%
cm_corr_2020_03_01_2021_03_01 = Correlation(csv_files = ['stats_output/BEA_aggregated_df_2020-03-01_2021-03-01.csv',\
                                   'stats_output/CQEA_aggregated_df_2020-03-01_2021-03-01.csv', \
                                  'stats_output/FJEA_aggregated_df_2020-03-01_2021-03-01.csv', \
                                  'stats_output/GDEA_aggregated_df_2020-03-01_2021-03-01.csv', \
                                  'stats_output/HBEA_aggregated_df_2020-03-01_2021-03-01.csv', \
                                  'stats_output/SHEA_aggregated_df_2020-03-01_2021-03-01.csv', \
                                  'stats_output/SZA_2015_aggregated_df_2020-03-01_2021-03-01.csv', \
                                  'stats_output/TJEA_aggregated_df_2020-03-01_2021-03-01.csv'], start_date = '2020-03-01', end_date = '2021-03-01', to_csv = False)
cm_corr_2020_03_01_2021_03_01.get_correlation()

# %%
tianjin = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/tianjin_spider/tianjin_spider/spiders/tianjin_.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'TJEA', risk_free = 0.02388, start_date = '2018-01-01', end_date = '2020-12-31', to_csv = False)
tianjin.get_stats()
# Out:
# TJEA carbon market metrics from 2018-01-01 to 2020-12-31
# >> Total Return:  140.0%
# >> Annualised return over months:  33.8866%
# >> Annualised return over years:  54.9193%
# >> Standard Deviation:  0.0562
# >> Annualised volatility:  0.8881
# >> Sharpe ratio:  0.5915
# >> Skewnesss:  1.0529
# >> Kurtosis:  16.1507
# >> Maximum drawdown:  -33.67%

# %%
guangdong = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/guangdong_spider/guangdong_spider/spiders/guangdong_GDEA.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'GDEA', risk_free = 0.02388, start_date = '2018-01-01', end_date = '2020-12-31', to_csv = False)
guangdong.get_stats()
# Out:
# GDEA carbon market metrics from 2018-01-01 to 2020-12-31
# >> Total Return:  119.7216%
# >> Annualised return over months:  30.0043%
# >> Annualised return over years:  48.2301%
# >> Standard Deviation:  0.0296
# >> Annualised volatility:  0.468
# >> Sharpe ratio:  0.9796
# >> Skewnesss:  0.0783
# >> Kurtosis:  3.1477
# >> Maximum drawdown:  -26.61%

# %%
beijing = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/beijing_spider/beijing_spider/spiders/beijing_BEA.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'BEA', risk_free = 0.02388, start_date = '2018-01-01', end_date = '2020-12-31', to_csv = False)
beijing.get_stats()
# Out:
# BEA carbon market metrics from 2018-01-01 to 2020-12-31
# >> Total Return:  85.1852%
# >> Annualised return over months:  22.801%
# >> Annualised return over years:  36.0828%
# >> Standard Deviation:  0.0786
# >> Annualised volatility:  1.2432
# >> Sharpe ratio:  0.271
# >> Skewnesss:  -0.2239
# >> Kurtosis:  1.6164
# >> Maximum drawdown:  -57.24%

# %%
hubei = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/hubei_spider/hubei_spider/spiders/hubei_HBEA.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'HBEA', risk_free = 0.02388, start_date = '2018-01-01', end_date = '2020-12-31', to_csv = False)
hubei.get_stats()
# Out:
# HBEA carbon market metrics from 2018-01-01 to 2020-12-31
# >> Total Return:  83.782%
# >> Annualised return over months:  22.4901%
# >> Annualised return over years:  35.5662%
# >> Standard Deviation:  0.0303
# >> Annualised volatility:  0.4789
# >> Sharpe ratio:  0.6928
# >> Skewnesss:  0.112
# >> Kurtosis:  2.3108
# >> Maximum drawdown:  -54.52%

# %%
chongqing = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/tanjiaoyi/chongqing_spider/chongqing_spider/spiders/chongqing_CQEA.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'CQEA', risk_free = 0.02388, start_date = '2018-01-01', end_date = '2020-12-31', to_csv = False)
chongqing.get_stats()
# Out:
# CQEA carbon market metrics from 2018-01-01 to 2020-12-31
# >> Total Return:  102.0374%
# >> Annualised return over months:  26.4185%
# >> Annualised return over years:  42.1398%
# >> Standard Deviation:  0.1172
# >> Annualised volatility:  1.8523
# >> Sharpe ratio:  0.2146
# >> Skewnesss:  2.1886
# >> Kurtosis:  20.3517
# >> Maximum drawdown:  -92.98%

# %%
fujian = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/tanjiaoyi/fujian_spider/fujian_spider/spiders/fujian_FJEA.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'FJEA', risk_free = 0.02388, start_date = '2018-01-01', end_date = '2020-12-31', to_csv = False)
fujian.get_stats()
# Out:
# FJEA carbon market metrics from 2018-01-01 to 2020-12-31
# >> Total Return:  -7.0835%
# >> Annualised return over months:  -2.4192%
# >> Annualised return over years:  -3.6068%
# >> Standard Deviation:  0.0531
# >> Annualised volatility:  0.8401
# >> Sharpe ratio:  -0.0714
# >> Skewnesss:  -0.4316
# >> Kurtosis:  2.8858
# >> Maximum drawdown:  -76.07%

# %%
shenzhen = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/shenzhen_spider/shenzhen_spider/spiders/shenzhen_SZA_2015.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'SZA_2015', risk_free = 0.02388, start_date = '2018-01-01', end_date = '2020-12-31', to_csv = False)
shenzhen.get_stats()
# Out:
# SZA_2015 carbon market metrics from 2018-01-01 to 2020-12-31
# >> Total Return:  -85.6857%
# >> Annualised return over months:  -47.6894%
# >> Annualised return over years:  -62.1658%
# >> Standard Deviation:  0.0589
# >> Annualised volatility:  0.9312
# >> Sharpe ratio:  -0.6932
# >> Skewnesss:  -0.0129
# >> Kurtosis:  0.1852
# >> Maximum drawdown:  -92.22%

# %%
shanghai = Stats(csv_file = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/tanjiaoyi/shanghai_spider/shanghai_spider/spiders/shanghai_SHEA.csv','/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv'], trading_index = 'SHEA', risk_free = 0.02388, start_date = '2018-01-01', end_date = '2020-12-31', to_csv = False)
shanghai.get_stats()
# Out:
# SHEA carbon market metrics from 2018-01-01 to 2020-12-31
# >> Total Return:  11.4286%
# >> Annualised return over months:  3.673%
# >> Annualised return over years:  5.5597%
# >> Standard Deviation:  0.0518
# >> Annualised volatility:  0.8187
# >> Sharpe ratio:  0.0387
# >> Skewnesss:  0.7209
# >> Kurtosis:  5.3701
# >> Maximum drawdown:  -42.22%

# %%
cm_corr_2018_01_01_2020_12_31 = Correlation(csv_files = ['stats_output/BEA_aggregated_df_2018-01-01_2020-12-31.csv',\
                                   'stats_output/CQEA_aggregated_df_2018-01-01_2020-12-31.csv', \
                                  'stats_output/FJEA_aggregated_df_2018-01-01_2020-12-31.csv', \
                                  'stats_output/GDEA_aggregated_df_2018-01-01_2020-12-31.csv', \
                                  'stats_output/HBEA_aggregated_df_2018-01-01_2020-12-31.csv', \
                                  'stats_output/SHEA_aggregated_df_2018-01-01_2020-12-31.csv', \
                                  'stats_output/SZA_2015_aggregated_df_2018-01-01_2020-12-31.csv', \
                                  'stats_output/TJEA_aggregated_df_2018-01-01_2020-12-31.csv'], start_date = '2018-01-01', end_date = '2020-12-31', to_csv = False)
cm_corr_2018_01_01_2020_12_31.get_correlation()

# %%
from merge_df.merge_df import merge_df

csv_files = ['/Users/xuhuili/Desktop/ccm_project/web_scraping/tanjiaoyi/chongqing_spider/chongqing_spider/spiders/chongqing_CQEA.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/tanjiaoyi/fujian_spider/fujian_spider/spiders/fujian_FJEA.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/tanjiaoyi/shanghai_spider/shanghai_spider/spiders/shanghai_SHEA.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/hubei_spider/hubei_spider/spiders/hubei_HBEA.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/tianjin_spider/tianjin_spider/spiders/tianjin_TJEA13.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/tianjin_spider/tianjin_spider/spiders/tianjin_TJEA14.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/tianjin_spider/tianjin_spider/spiders/tianjin_TJEA15.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/tianjin_spider/tianjin_spider/spiders/tianjin_TJEA16.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/tianjin_spider/tianjin_spider/spiders/tianjin_TJEA17.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/tianjin_spider/tianjin_spider/spiders/tianjin_TJEA18.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/tianjin_spider/tianjin_spider/spiders/tianjin_TJEA19.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/tianjin_spider/tianjin_spider/spiders/tianjin_TJEA20.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/beijing_spider/beijing_spider/spiders/beijing_BEA.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/beijing_spider/beijing_spider/spiders/beijing_CCER.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/beijing_spider/beijing_spider/spiders/beijing_林业碳汇.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/shenzhen_spider/shenzhen_spider/spiders/shenzhen_SZA_2013.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/shenzhen_spider/shenzhen_spider/spiders/shenzhen_SZA_2014.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/shenzhen_spider/shenzhen_spider/spiders/shenzhen_SZA_2015.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/shenzhen_spider/shenzhen_spider/spiders/shenzhen_SZA_2016.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/shenzhen_spider/shenzhen_spider/spiders/shenzhen_SZA_2017.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/shenzhen_spider/shenzhen_spider/spiders/shenzhen_SZA_2018.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/shenzhen_spider/shenzhen_spider/spiders/shenzhen_SZA_2019.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/shenzhen_spider/shenzhen_spider/spiders/shenzhen_SZA_2020.csv',
             '/Users/xuhuili/Desktop/ccm_project/web_scraping/guangdong_spider/guangdong_spider/spiders/guangdong_GDEA.csv']

merge_df(csv_files = csv_files, comparator_csv = '/Users/xuhuili/Desktop/ccm_project/Comparator_indices_07062021.csv', to_csv = False)
# Out:
#                    Trading Index        Date  Settlement Price (yuan/ton)  \
# 0                           CQEA  2017-02-08                        19.99
# 1                           CQEA  2017-02-09                        19.99
# 2                           CQEA  2017-02-10                        19.99
# 3                           CQEA  2017-02-13                        19.99
# 4                           CQEA  2017-02-14                        19.99
# ...                          ...         ...                          ...
# 4104  S&P 500 Total Return Index  2021-03-28                      8240.38
# 4105  S&P 500 Total Return Index  2021-03-29                      8233.24
# 4106  S&P 500 Total Return Index  2021-03-30                      8208.10
# 4107  S&P 500 Total Return Index  2021-03-31                      8238.48
# 4108  S&P 500 Total Return Index  2021-04-01                      8335.91
#
#      Settlement Volume (ton)
# 0                          0
# ...
